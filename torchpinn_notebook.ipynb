# %%
# import numpy as np
# from sklearn import preprocessing
# import torch
import pandas as pd
import matplotlib.pyplot as plt

from torchpinn import PinnInference

# %%
df = pd.read_pickle("data_demo_pinn_bioz_bp", compression="gzip")

# %%
df
# Out:
#      trial_id                                         bioz_beats  phys_feat_1  \
# 0           1  [4.674306050529548e-06, 3.873631220239295e-06,...     5.817552
# 1           1  [4.806376660377724e-06, 4.00727594328936e-06, ...     6.002678
# 2           1  [4.4183450820834e-06, 3.6333050096782107e-06, ...     5.632601
# 3           1  [4.076650431880851e-06, 3.4283849875982737e-06...     5.119284
# 4           1  [3.848732650901477e-06, 3.1940944086055694e-06...     4.833644
# ..        ...                                                ...          ...
# 903        10  [4.451317036264093e-06, 3.7883056214844768e-06...     6.085810
# 904        10  [3.795763015166559e-06, 3.243015857592363e-06,...     5.374167
# 905        10  [3.64505045508789e-06, 3.1356280267987126e-06,...     5.097898
# 906        10  [4.094566392770898e-06, 3.5499874384746767e-06...     5.533029
# 907        10  [4.260339350256855e-06, 3.612471086421771e-06,...     5.869684
#
#      phys_feat_2  phys_feat_3         sys
# 0     905.797101    97.832540  141.154438
# 1     905.923964    99.785117  143.502124
# 2     897.170462   100.450450  147.810844
# 3     919.250190   102.752581  150.845861
# 4     914.810008   102.519611  153.840739
# ..           ...          ...         ...
# 903   932.974388    95.140808  148.113181
# 904   897.418827    93.771980  154.844048
# 905   892.978645    90.376871  154.553150
# 906   905.923964    91.289813  150.116754
# 907   884.473508    90.735448  148.594091
#
# [908 rows x 6 columns]

# %%
inference = PinnInference("pinn_model.pth", "cpu")

# %%
index = 0
inference.predict(df["bioz_beats"][index], df["phys_feat_1"][index], df["phys_feat_2"][index], df["phys_feat_3"][index])
# Out:
# array([[140.85828]], dtype=float32)

# %%
for i in range(908):
    plt.plot(df["bioz_beats"][i], alpha=0.1)
